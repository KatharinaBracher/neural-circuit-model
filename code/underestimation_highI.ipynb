# %%
import numpy as np
import matplotlib.pyplot as plt

import parameter_tuning as pt

# %%
from onetwogo import Params
from onetwogo.parallel_simulation import ParallelSimulation
from onetwogo.experiment_simulation import ExperimentSimulation
from onetwogo.plot import SimulationPlot
from onetwogo.plot import BehavioralPlot
from onetwogo.plot import SortedPlot

# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib as mpl
from matplotlib import rc

rc('text', usetex=True)
font = {'family':'CMU Serif', 
               #'sans-serif':['Helvetica'],
               'size': 11}
mpl.rc('font', **font)

# %%
stimulus_short = np.loadtxt('stimlst_short_400_700_7_a.txt', dtype=int)
stimulus_long = np.loadtxt('stimlst_long_700_1000_7_a.txt', dtype=int)
range_short = [400, 450, 500, 550, 600, 650, 700]
range_long = [700, 750, 800, 850, 900, 950, 1000]

# %% [markdown]
# ## Th 0.2

# %%
np.random.seed(0)
params = Params(ntrials=500, delay=700, tau=70, sigma=0.02, th=0.2, Iinit=1.02, IF=-500)
expsim = ExperimentSimulation(params)

fig, ax = plt.subplots(1,1, figsize=(2.5,2))

K = 3
exp_result = expsim.simulate(stimulus_short, K)
plot = exp_result.create_behavioral_plot()
plot.plot_behavior(ax)
print(exp_result.create_behavioral_data().slope)

np.random.seed(0)
K = 2
exp_result = expsim.simulate(stimulus_long, K)
plot = exp_result.create_behavioral_plot()
plot.plot_behavior(ax)
print(exp_result.create_behavioral_data().slope)

ax.set(xlabel='stimulus [ms]', ylabel='reproduction [ms]')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False) 

plt.tight_layout()
# Out:
# timeouts: [(400, 0.0), (450, 0.0), (500, 0.0), (550, 0.0), (600, 0.0), (650, 0.0), (700, 0.0)]
# 0.6236449065697234
# timeouts: [(700, 0.0), (750, 0.0), (800, 0.0), (850, 0.0), (900, 0.0), (950, 0.0), (1000, 0.0)]
# 0.5468865458799695

# %%
np.random.seed(0)
params = Params(ntrials=500, delay=700, sigma=0.02, th=0.2, Iinit=1.02, IF=-500, tau=70)
expsimS = ExperimentSimulation(params)

K = 3
exp_resultS = expsimS.simulate(stimulus_short, K)

# %%
plot = SortedPlot(exp_resultS.create_sorted_data(2))
plot.plot_sorted()

# %%
np.random.seed(0)
params = Params(ntrials=500, delay=700, sigma=0.02, th=0.2, Iinit=1.02, IF=-500, tau=70)
expsimL = ExperimentSimulation(params)

K = 2
exp_resultL = expsimL.simulate(stimulus_long, K)

# %%
plot = SortedPlot(exp_resultL.create_sorted_data(2))
plot.plot_sorted()

# %%
# slides into intermediate regime

# %% [markdown]
# ## Th 0.05

# %%
np.random.seed(0)
params = Params(ntrials=500, delay=700, sigma=0.02, th=0.05, Iinit=1.02, IF=-500, tau=60)
expsim = ExperimentSimulation(params)

fig, ax = plt.subplots(1,1, figsize=(2.5,2))

K = 6.5
exp_result = expsim.simulate(stimulus_short, K)
plot = exp_result.create_behavioral_plot()
plot.plot_behavior(ax)
print(exp_result.create_behavioral_data().slope)

np.random.seed(0)
K = 4
exp_result = expsim.simulate(stimulus_long, K)
plot = exp_result.create_behavioral_plot()
plot.plot_behavior(ax)
print(exp_result.create_behavioral_data().slope)

ax.set(xlabel='stimulus [ms]', ylabel='reproduction [ms]')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False) 

plt.tight_layout()
# Out:
# timeouts: [(400, 0.0), (450, 0.0), (500, 0.0), (550, 0.0), (600, 0.0), (650, 0.0), (700, 0.0)]
# 0.6253449731848496
# timeouts: [(700, 0.0), (750, 0.0), (800, 0.0), (850, 0.0), (900, 0.0), (950, 0.0), (1000, 0.0)]
# 0.6304025094708323

# %%
np.random.seed(0)
params = Params(ntrials=500, delay=700, sigma=0.02, th=0.05, Iinit=1.02, IF=-500, tau=60)
expsimS = ExperimentSimulation(params)

K = 6.5
exp_resultS = expsimS.simulate(stimulus_short, K)

# %%
plot = SortedPlot(exp_resultS.create_sorted_data(2))
plot.plot_sorted()

# %%
np.random.seed(0)
params = Params(ntrials=500, delay=700, sigma=0.02, th=0.05, Iinit=1.02, IF=-500, tau=60)
expsimL = ExperimentSimulation(params)

K = 4
exp_resultL = expsimL.simulate(stimulus_long, K)

# %%
plot = SortedPlot(exp_resultL.create_sorted_data(2))
plot.plot_sorted()

# %%
###############################################

# %%
np.random.seed(0)
params = Params(ntrials=500, delay=700, sigma=0.02, th=0.2, Iinit=1.02, IF=-500, tau=70)
expsim = ExperimentSimulation(params)

fig, ax = plt.subplots(1,1, figsize=(2.5,2))

K = 9.5
exp_result = expsim.simulate(stimulus_short, K)
plot = exp_result.create_behavioral_plot()
plot.plot_behavior(ax)
print(exp_result.create_behavioral_data().slope)

np.random.seed(0)
K = 9
exp_result = expsim.simulate(stimulus_long, K)
plot = exp_result.create_behavioral_plot()
plot.plot_behavior(ax)
print(exp_result.create_behavioral_data().slope)

ax.set(xlabel='stimulus [ms]', ylabel='reproduction [ms]')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False) 

plt.tight_layout()

# %%
np.random.seed(0)
params = Params(ntrials=500, delay=700, sigma=0.02, th=0.2, Iinit=1.02, IF=-500, tau=70)
expsimS = ExperimentSimulation(params)

K = 9.5
exp_resultS = expsimS.simulate(stimulus_short, K)

# %%
plot = SortedPlot(exp_resultS.create_sorted_data(2))
plot.plot_sorted()

# %%
np.random.seed(0)
params = Params(ntrials=500, delay=700, sigma=0.02, th=0.2, Iinit=1.02, IF=-500, tau=70)
expsimL = ExperimentSimulation(params)

K = 9
exp_resultL = expsimL.simulate(stimulus_long, K)

# %%
plot = SortedPlot(exp_resultL.create_sorted_data(2))
plot.plot_sorted()

# %% [markdown]
# # delay

# %%
K_lst = np.arange(1, 35, 1)
tau = np.arange(20, 200, 10)

# %%
path = '../results/underestimation/delayhigh/'
short_ktau7z, long_ktau7z = pt.load_data(path+'SHORT_K1-35_th1_seed_delay0-20221017-121334-output.pickle', 
                                      path+'LONG_K1-35_th1_seed_delay0-20221017-120224-output.pickle')

short_ktau7s, long_ktau7s = pt.load_data(path+'SHORT_K1-35_th1_seed_delay550-20221017-123511-output.pickle', 
                                      path+'LONG_K1-35_th1_seed_delay550-20221017-122039-output.pickle')

short_ktau7l, long_ktau7l = pt.load_data(path+'SHORT_K1-35_th1_seed_delay850-20221017-130145-output.pickle', 
                                      path+'LONG_K1-35_th1_seed_delay850-20221017-124524-output.pickle')

short_ktau7ll, long_ktau7ll = pt.load_data(path+'SHORT_K1-35_th1_seed_delay1000-20221017-133035-output.pickle', 
                                      path+'LONG_K1-35_th1_seed_delay1000-20221017-131339-output.pickle')

# %%
np.random.seed(0)
params = Params(ntrials=500, delay=0, tau=50, sigma=0.02, th=0.05, Iinit=1.02, IF=-500)
expsim = ExperimentSimulation(params)

fig, ax = plt.subplots(1,1, figsize=(2.5,2))

K = 6
exp_result = expsim.simulate(stimulus_long, K)
plot = exp_result.create_behavioral_plot()
plot.plot_behavior(ax)
print(exp_result.create_behavioral_data().slope)

ax.set(xlabel='stimulus [ms]', ylabel='reproduction [ms]')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False) 

plt.tight_layout()
# Out:
# timeouts: [(700, 0.0), (750, 0.0), (800, 0.0), (850, 0.0), (900, 0.0), (950, 0.03), (1000, 0.07)]
# 1.3709427777226688

# %%
pt.plot_mse(short_ktau7z, long_ktau7z, K_lst, tau)
print(pt.get_opt_K(short_ktau7z, K_lst, tau, mse=True))
print(pt.get_opt_K(long_ktau7z, K_lst, tau, mse=True))
pt.parameter_behavioural_plausible(short_ktau7z, long_ktau7z, K_lst, tau)
# Out:
# 6809.254887147487 51220.42959446896
# 50 3
# [(20, 1), (30, 1), (40, 2), (50, 3), (60, 4), (70, 6), (80, 9), (90, 11), (100, 15), (110, 17), (120, 21), (130, 23), (140, 26), (150, 28), (160, 28), (170, 24), (180, 29), (190, 7)]
# 70 4
# [(20, 1), (30, 1), (40, 1), (50, 2), (60, 3), (70, 4), (80, 5), (90, 7), (100, 9), (110, 11), (120, 13), (130, 15), (140, 17), (150, 23), (160, 24), (170, 24), (180, 29), (190, 30)]
# short range
# ['2,40' '3,50' '9,80' '15,100' '19,110' '23,120' '24,120' '29,130'
#  '30,130' '31,130']
# long range
# ['2,50' '4,70' '7,90' '9,100' '11,110' '13,120' '16,130' '19,140' '23,150'
#  '27,160' '31,170']

# %%
np.random.seed(0)
params = Params(ntrials=500, delay=0, tau=70, sigma=0.02, th=0.1, Iinit=1.02, IF=-500)
expsim = ExperimentSimulation(params)

fig, ax = plt.subplots(1,1, figsize=(2.5,2))

K = 4
exp_result = expsim.simulate(stimulus_long, K)
plot = exp_result.create_behavioral_plot()
plot.plot_behavior(ax)
print(exp_result.create_behavioral_data().slope)

ax.set(xlabel='stimulus [ms]', ylabel='reproduction [ms]')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False) 

plt.tight_layout()
# Out:
# timeouts: [(700, 0.0), (750, 0.0), (800, 0.0), (850, 0.0), (900, 0.0), (950, 0.0), (1000, 0.0)]
# 0.7677209088955526

# %%
np.random.seed(0)
params = Params(ntrials=500, delay=0, tau=60, sigma=0.02, th=0.1, Iinit=1.02, IF=-500)
expsim = ExperimentSimulation(params)

fig, ax = plt.subplots(1,1, figsize=(2.5,2))

K = 4
exp_result = expsim.simulate(stimulus_short, K)
plot = exp_result.create_behavioral_plot()
plot.plot_behavior(ax)
print(exp_result.create_behavioral_data().slope)

np.random.seed(0)
K = 3
exp_result = expsim.simulate(stimulus_long, K)
plot = exp_result.create_behavioral_plot()
plot.plot_behavior(ax)
print(exp_result.create_behavioral_data().slope)

ax.set(xlabel='stimulus [ms]', ylabel='reproduction [ms]')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False) 

plt.tight_layout()
# Out:
# timeouts: [(400, 0.0), (450, 0.0), (500, 0.0), (550, 0.0), (600, 0.0), (650, 0.0), (700, 0.0)]
# 0.667800897043504
# timeouts: [(700, 0.0), (750, 0.0), (800, 0.0), (850, 0.0), (900, 0.0), (950, 0.0), (1000, 0.0)]
# 0.8107251008511513

# %%
np.random.seed(0)
params = Params(ntrials=500, delay=0, sigma=0.02, th=0.1, Iinit=1.02, IF=-500, tau=60)
expsimS = ExperimentSimulation(params)

K = 4
exp_resultS = expsimS.simulate(stimulus_short, K)

# %%
plot = SortedPlot(exp_resultS.create_sorted_data(2))
plot.plot_sorted()

# %%
np.random.seed(0)
params = Params(ntrials=500, delay=0, sigma=0.02, th=0.1, Iinit=1.02, IF=-500, tau=60)
expsimL = ExperimentSimulation(params)

K = 3
exp_resultL = expsimL.simulate(stimulus_long, K)

# %%
plot = SortedPlot(exp_resultL.create_sorted_data(2))
plot.plot_sorted()

# %%
def mean_I(sorted_data):
    mean_I = []
    for s in range(7):
        summe = 0
        for i in range(len(sorted_data.I_sorted[s])):
            summe += sorted_data.I_sorted[s][i][1][0]
        mean_I.append(summe/len(sorted_data.I_sorted[s]))
    return mean_I

fig, ax = plt.subplots(1,1, figsize=(2.,1.8))

ax.plot(range_short, mean_I(exp_resultS.create_sorted_data(2)), c='k')
ax.plot(range_long, mean_I(exp_resultL.create_sorted_data(2)), c='grey')

ax.set_xlabel('stimulus [ms]', fontdict=font)
ax.set_ylabel('mean '+r'$I$')

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

plt.tight_layout()

# %%
pt.plot_mse(short_ktau7s, long_ktau7s, K_lst, tau)
print(pt.get_opt_K(short_ktau7s, K_lst, tau, mse=True))
print(pt.get_opt_K(long_ktau7s, K_lst, tau, mse=True))
pt.parameter_behavioural_plausible(short_ktau7s, long_ktau7s, K_lst, tau)
# Out:
# 5974.5588025911575 86804.26521746902
# 60 4
# [(20, 1), (30, 1), (40, 2), (50, 3), (60, 4), (70, 6), (80, 8), (90, 10), (100, 13), (110, 13), (120, 18), (130, 19), (140, 18), (150, 25), (160, 21), (170, 21), (180, 23), (190, 27)]
# 50 2
# [(20, 1), (30, 1), (40, 1), (50, 2), (60, 2), (70, 3), (80, 5), (90, 6), (100, 8), (110, 10), (120, 11), (130, 14), (140, 16), (150, 14), (160, 18), (170, 18), (180, 19), (190, 18)]
# short range
# ['2,40' '3,50' '9,80' '12,90' '15,100' '19,110']
# long range
# ['4,70' '7,90' '9,100' '12,110' '14,120' '15,120' '18,130' '19,130'
#  '22,140' '24,150']

# %%
np.random.seed(0)
params = Params(ntrials=500, delay=550, tau=60, sigma=0.02, th=0.1, Iinit=1.02, IF=-500)
expsim = ExperimentSimulation(params)

fig, ax = plt.subplots(1,1, figsize=(2.5,2))

K = 4
exp_result = expsim.simulate(stimulus_short, K)
plot = exp_result.create_behavioral_plot()
plot.plot_behavior(ax)
print(exp_result.create_behavioral_data().slope)

np.random.seed(0)
K = 2
exp_result = expsim.simulate(stimulus_long, K)
plot = exp_result.create_behavioral_plot()
plot.plot_behavior(ax)
print(exp_result.create_behavioral_data().slope)

ax.set(xlabel='stimulus [ms]', ylabel='reproduction [ms]')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False) 

plt.tight_layout()
# Out:
# timeouts: [(400, 0.0), (450, 0.0), (500, 0.0), (550, 0.0), (600, 0.0), (650, 0.0), (700, 0.0)]
# 0.6514775252658815
# timeouts: [(700, 0.0), (750, 0.0), (800, 0.0), (850, 0.0), (900, 0.0), (950, 0.0), (1000, 0.0)]
# 0.47404385426855294

# %%
pt.plot_mse(short_ktau7l, long_ktau7l, K_lst, tau)
print(pt.get_opt_K(short_ktau7l, K_lst, tau, mse=True))
print(pt.get_opt_K(long_ktau7l, K_lst, tau, mse=True))
pt.parameter_behavioural_plausible(short_ktau7l, long_ktau7l, K_lst, tau)
# Out:
# 6058.110418974653 87583.7509804061
# 50 3
# [(20, 1), (30, 1), (40, 2), (50, 3), (60, 4), (70, 5), (80, 7), (90, 9), (100, 11), (110, 12), (120, 14), (130, 17), (140, 18), (150, 19), (160, 19), (170, 22), (180, 27), (190, 25)]
# 70 4
# [(20, 1), (30, 1), (40, 1), (50, 2), (60, 3), (70, 4), (80, 5), (90, 6), (100, 8), (110, 9), (120, 11), (130, 13), (140, 15), (150, 15), (160, 17), (170, 18), (180, 20), (190, 21)]
# short range
# ['3,50' '4,60' '6,70' '8,80' '10,90' '13,100' '14,100' '17,110' '18,110']
# long range
# ['2,50' '3,60' '4,70' '7,90' '9,100' '11,110' '14,120' '15,120' '16,120'
#  '18,130' '21,140']

# %%
np.random.seed(0)
params = Params(ntrials=500, delay=850, tau=70, sigma=0.02, th=0.1, Iinit=1.02, IF=-500)
expsim = ExperimentSimulation(params)

fig, ax = plt.subplots(1,1, figsize=(2.5,2))

K = 5
exp_result = expsim.simulate(stimulus_short, K)
plot = exp_result.create_behavioral_plot()
plot.plot_behavior(ax)
print(exp_result.create_behavioral_data().slope)

np.random.seed(0)
K = 4
exp_result = expsim.simulate(stimulus_long, K)
plot = exp_result.create_behavioral_plot()
plot.plot_behavior(ax)
print(exp_result.create_behavioral_data().slope)

ax.set(xlabel='stimulus [ms]', ylabel='reproduction [ms]')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False) 

plt.tight_layout()
# Out:
# timeouts: [(400, 0.0), (450, 0.0), (500, 0.0), (550, 0.0), (600, 0.0), (650, 0.0), (700, 0.0)]
# 0.6820086833856881
# timeouts: [(700, 0.0), (750, 0.0), (800, 0.0), (850, 0.0), (900, 0.0), (950, 0.0), (1000, 0.0)]
# 0.7167476040731429

# %%
pt.plot_mse(short_ktau7ll, long_ktau7ll, K_lst, tau)
print(pt.get_opt_K(short_ktau7ll, K_lst, tau, mse=True))
print(pt.get_opt_K(long_ktau7ll, K_lst, tau, mse=True))
pt.parameter_behavioural_plausible(short_ktau7ll, long_ktau7ll, K_lst, tau)
# Out:
# 6615.310777466613 74447.07485677968
# 50 2
# [(20, 1), (30, 1), (40, 1), (50, 2), (60, 3), (70, 5), (80, 6), (90, 8), (100, 9), (110, 11), (120, 14), (130, 15), (140, 17), (150, 18), (160, 19), (170, 21), (180, 26), (190, 32)]
# 70 3
# [(20, 1), (30, 1), (40, 1), (50, 1), (60, 2), (70, 3), (80, 4), (90, 5), (100, 7), (110, 8), (120, 10), (130, 12), (140, 13), (150, 16), (160, 15), (170, 16), (180, 17), (190, 17)]
# short range
# ['3,50' '4,60' '10,90' '12,100' '13,100']
# long range
# ['5,80' '8,100' '10,110' '12,120' '13,120' '15,120' '15,130' '16,130']

# %%
np.random.seed(0)
params = Params(ntrials=500, delay=1000, tau=60, sigma=0.02, th=0.1, Iinit=1.02, IF=-500)
expsim = ExperimentSimulation(params)

fig, ax = plt.subplots(1,1, figsize=(2.5,2))

K = 3
exp_result = expsim.simulate(stimulus_short, K)
plot = exp_result.create_behavioral_plot()
plot.plot_behavior(ax)
print(exp_result.create_behavioral_data().slope)

np.random.seed(0)
K = 2
exp_result = expsim.simulate(stimulus_long, K)
plot = exp_result.create_behavioral_plot()
plot.plot_behavior(ax)
print(exp_result.create_behavioral_data().slope)

ax.set(xlabel='stimulus [ms]', ylabel='reproduction [ms]')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False) 

plt.tight_layout()
# Out:
# timeouts: [(400, 0.0), (450, 0.0), (500, 0.0), (550, 0.0), (600, 0.0), (650, 0.0), (700, 0.0)]
# 0.5192453041055525
# timeouts: [(700, 0.0), (750, 0.0), (800, 0.0), (850, 0.0), (900, 0.0), (950, 0.0), (1000, 0.0)]
# 0.4469309522762208
